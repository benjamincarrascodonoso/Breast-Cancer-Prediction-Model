# %%
import pickle
import matplotlib.pyplot as plt
import tensorflow as tf
from glob import glob
from PIL import Image
import numpy as np
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Load all histories
history1 = pickle.load(open('./files/S10/History1Dict', 'rb'))
history2 = pickle.load(open('./files/S10/History2Dict', 'rb'))
history3 = pickle.load(open('./files/S10/History3Dict', 'rb'))

# Sum all histories into one
total_history = dict()


for some_key in history1.keys():
    current_values = [] # to save values from all three hist dicts
    for hist_dict in [history1, history2, history3]:
        current_values += hist_dict[some_key]
    total_history[some_key] = current_values

# %% [markdown]
# # Training Metrics
#
# ## Training Loss

# %%
plt.figure(figsize=(16,10))
plt.plot(total_history['loss'])
plt.plot(total_history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ## Training Accuracy

# %%
plt.figure(figsize=(16,10))
plt.plot(total_history['accuracy'])
plt.plot(total_history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# # Testing Metrics

# %% [markdown]
# ## Setup

# %%
X_train = []

dirs = glob('./datasets/S10/train/*/', recursive=True)
for dir in dirs:
    # Get only one patch from each image to not run out of memory for the .fit
    for infile in glob(dir + '*.png')[::10]:
        im = Image.open(infile)         # Loads in PIL format L (grayscale 8 bit)
        im = im.convert('RGB')          # Convert to RGB for fitting 
        X_train.append(np.array(im))

X_train = np.array(X_train)

# %% [markdown]
# ## Accuracy and Loss

# %%
model = tf.keras.models.load_model('./models/S10_model.h5')

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    featurewise_center=True,                 # Substract mean value of the training dataset
)
# Fit the test_datagen on the training data
test_datagen.fit(X_train)

test_generator = test_datagen.flow_from_directory(
    './datasets/S10/test/',
    target_size=(224,224),
    batch_size=32,
    shuffle=False,
    class_mode='categorical'
)
# Out:
# 2022-09-07 18:03:46.820168: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 18:03:46.847587: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 18:03:46.847760: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 18:03:46.848668: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-07 18:03:46.849112: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 18:03:46.849271: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 18:03:46.849417: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 18:03:47.127892: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 18:03:47.128080: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 18:03:47.128218: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 18:03:47.128329: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5335 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 6.1
# Found 10878 images belonging to 5 classes.

# %%
# Returns Test Metrics
model.evaluate(test_generator)
# Out:
# 2022-09-07 18:04:29.944562: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401
# 340/340 [==============================] - 59s 158ms/step - loss: 0.6315 - accuracy: 0.7667 - tp: 7694.0000 - fp: 1665.0000 - tn: 41847.0000 - fn: 3184.0000 - precision: 0.8221 - recall: 0.7073 - auc: 0.9499 - prc: 0.8623
# [0.6315464377403259,
#  0.7666850686073303,
#  7694.0,
#  1665.0,
#  41847.0,
#  3184.0,
#  0.8220964074134827,
#  0.7072991132736206,
#  0.9499415159225464,
#  0.862275242805481]

# %% [markdown]
# ## Confusion Matrix

# %%
# Predict on all test images
preds = model.predict(test_generator)
# Out:
# 340/340 [==============================] - 53s 153ms/step

# %%
# Get the predict label for each image and give 1d format for confusion matrix
pred_labels = np.argmax(preds, axis=1)

# Get the ground truth labels
true_labels = test_generator.classes

# Plot confusion matrix
titles_options = [
    ('Confusion Matrix, without normalization', None),
    ('Normalized Confusion Matrix', 'true')
]

print(test_generator.class_indices)
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_predictions(
        true_labels,
        pred_labels,
        #display_labels=test_generator.class_indices,
        cmap=plt.cm.Blues,
        normalize=normalize)
    disp.ax_.set_title(title)
    disp.figure_.set(figwidth=16, figheight=10)
    plt.show()
# Out:
# {'background': 0, 'calcification_BENIGN': 1, 'calcification_MALIGNANT': 2, 'mass_BENIGN': 3, 'mass_MALIGNANT': 4}

# %% [markdown]
# # Images

# %% [markdown]
# ## Setup

# %%
# Print prediction results in a grid
def plot_img_results(array, true, pred, i, n=1):
    # Plot the image and the target for sample i
    ncols = 3
    nrows = n//ncols + 1
    fig = plt.figure(figsize=(ncols*5, nrows*5))
    for j in range(n):
        index = j+i
        plt.subplot(nrows,ncols, j+1)
        plt.imshow(array[index].astype(np.uint8))
        plt.title('True: {}, Pred: {}'.format(true[index], pred[index]))
        plt.axis('off')

# %%
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    #featurewise_center=True,                 # Substract mean value of the training dataset
)
# Fit the test_datagen on the training data
#test_datagen.fit(X_train)

test_generator = test_datagen.flow_from_directory(
    './datasets/S10/test/',
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)
# Out:
# Found 10878 images belonging to 5 classes.

# %% [markdown]
# ## Get Labels

# %%
# Predict over the test dataset and see a few samples of correct/incorrect images
X_test, y_test = next(test_generator)
preds = model.predict(X_test)
pred_labels = np.argmax(preds, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Inverse the class mapping for easier understanding
rev_mapping = {v: k for k, v in test_generator.class_indices.items()}
# Out:
# 1/1 [==============================] - 1s 749ms/step

# %% [markdown]
# ## Mispredicted Images

# %%
# Find mispredicted labels
mispred_img = X_test[pred_labels!=true_labels]
mispred_true = true_labels[pred_labels!=true_labels]
mispred_pred = pred_labels[pred_labels!=true_labels]
print ('Number of misclassified images:', mispred_img.shape[0])
print()

print(rev_mapping)
plot_img_results(mispred_img, mispred_true, mispred_pred, 0, len(mispred_img))
# Out:
# Number of misclassified images: 9
#
# {0: 'background', 1: 'calcification_BENIGN', 2: 'calcification_MALIGNANT', 3: 'mass_BENIGN', 4: 'mass_MALIGNANT'}

# %% [markdown]
# ## Correct Predictions

# %%
# Find correctly predicted labels
pred_img = X_test[pred_labels==true_labels]
pred_true = true_labels[pred_labels==true_labels]
pred_pred = pred_labels[pred_labels==true_labels]
print ('Number of correctly classified images:', pred_img.shape[0])
print()

print(rev_mapping)
plot_img_results(pred_img, pred_true, pred_pred, 0, len(mispred_img))
# Out:
# Number of correctly classified images: 23
#
# {0: 'background', 1: 'calcification_BENIGN', 2: 'calcification_MALIGNANT', 3: 'mass_BENIGN', 4: 'mass_MALIGNANT'}
